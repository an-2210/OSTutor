# %% [markdown]
# # Supervised Attack Classification (XGBoost) Notebook
#
# Research artifact notebook: `05_advanced_models.ipynb`

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

print('Advanced classification model notebook initialized.')
