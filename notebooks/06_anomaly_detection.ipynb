# %% [markdown]
# # Unsupervised & Semi-Supervised Anomaly Detection Notebook
#
# Research artifact notebook: `06_anomaly_detection.ipynb`

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

print('Anomaly detection notebook initialized.')
