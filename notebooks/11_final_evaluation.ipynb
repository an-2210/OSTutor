# %% [markdown]
# # Ablation & Cross-Dataset Benchmark Synthesis Notebook
#
# Research artifact notebook: `11_final_evaluation.ipynb`

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

print('Final evaluation & experiment synthesis notebook initialized.')
