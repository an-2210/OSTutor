# %% [markdown]
# # MITRE ATT&CK Mapping & Evidence Extraction Notebook
#
# Research artifact notebook: `09_mitre_mapping.ipynb`

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

print('MITRE ATT&CK mapping notebook initialized.')
