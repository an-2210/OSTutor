# %% [markdown]
# # Retrieval-Augmented CTI Report Generation Notebook
#
# Research artifact notebook: `10_rag_cti.ipynb`

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

print('RAG threat intelligence notebook initialized.')
