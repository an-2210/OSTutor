# %% [markdown]
# # Data Quality & Leakage Audit Notebook
#
# Research artifact notebook: `02_data_quality.ipynb`

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

from src.utils.config import load_config
config = load_config('../configs/config.yaml')
print('Data quality audit notebook initialized.')
